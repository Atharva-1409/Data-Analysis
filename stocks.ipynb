# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("indexProcessed.csv")

# %%
print(df.head())
# Out:
#   Index      Date         Open         High          Low        Close  \
# 0   HSI  1/1/1986  2568.300049  2568.300049  2568.300049  2568.300049
# 1   HSI  1/1/1987  2540.100098  2540.100098  2540.100098  2540.100098
# 2   HSI  1/1/1988  2552.399902  2552.399902  2552.399902  2552.399902
# 3   HSI  1/1/1989  2583.899902  2583.899902  2583.899902  2583.899902
# 4   HSI  1/1/1990  2607.100098  2607.100098  2607.100098  2607.100098
#
#      Adj Close  Volume    CloseUSD
# 0  2568.300049       0  333.879006
# 1  2540.100098       0  330.213013
# 2  2552.399902       0  331.811987
# 3  2583.899902       0  335.906987
# 4  2607.100098       0  338.923013

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df = df.sort_values(by='Date')

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(8,6))

df = df.head(10)
sns.lineplot(data=df, x='Date', y='Close')

plt.title('Stock Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.xticks(rotation=45)

plt.show()
